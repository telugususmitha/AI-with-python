# %%
# !pip install tensorflow
# !pip install tensorflow.hub
# !pip install tensorflow.datasets

# %%
import numpy as np
import tensorflow as tf
import tensorflow_hub as hub
import tensorflow_datasets as tfds

# %%
train_data,val_data,test_data=tfds.load(name="imdb_reviews",
                                       split=("train","test[:40%]","test[40%:]"),
                                        as_supervised=True)
# Out:
# Downloading and preparing dataset 80.23 MiB (download: 80.23 MiB, generated: Unknown size, total: 80.23 MiB) to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Generating splits...:   0%|          | 0/3 [00:00<?, ? splits/s]
# Generating train examples...:   0%|          | 0/25000 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/imdb_reviews/plain_text/incomplete.3B8CPG_1.0.0/imdb_reviews-train.tfrecor…
# Generating test examples...:   0%|          | 0/25000 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/imdb_reviews/plain_text/incomplete.3B8CPG_1.0.0/imdb_reviews-test.tfrecord…
# Generating unsupervised examples...:   0%|          | 0/50000 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/imdb_reviews/plain_text/incomplete.3B8CPG_1.0.0/imdb_reviews-unsupervised.…
# Dataset imdb_reviews downloaded and prepared to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0. Subsequent calls will reuse this data.

# %%
print(train_data)
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(), dtype=tf.string, name=None), TensorSpec(shape=(), dtype=tf.int64, name=None))>

# %%
text,label = next(iter(train_data.batch(5)))

# %%
label
# Out:
# <tf.Tensor: shape=(5,), dtype=int64, numpy=array([0, 0, 0, 1, 1])>

# %%
text
# Out:
# <tf.Tensor: shape=(5,), dtype=string, numpy=
# array([b"This was an absolutely terrible movie. Don't be lured in by Christopher Walken or Michael Ironside. Both are great actors, but this must simply be their worst role in history. Even their great acting could not redeem this movie's ridiculous storyline. This movie is an early nineties US propaganda piece. The most pathetic scenes were those when the Columbian rebels were making their cases for revolutions. Maria Conchita Alonso appeared phony, and her pseudo-love affair with Walken was nothing but a pathetic emotional plug in a movie that was devoid of any real meaning. I am disappointed that there are movies like this, ruining actor's like Christopher Walken's good name. I could barely sit through it.",
#        b'I have been known to fall asleep during films, but this is usually due to a combination of things including, really tired, being warm and comfortable on the sette and having just eaten a lot. However on this occasion I fell asleep because the film was rubbish. The plot development was constant. Constantly slow and boring. Things seemed to happen, but with no explanation of what was causing them or why. I admit, I may have missed part of the film, but i watched the majority of it and everything just seemed to happen of its own accord without any real concern for anything else. I cant recommend this film at all.',
#        b'Mann photographs the Alberta Rocky Mountains in a superb fashion, and Jimmy Stewart and Walter Brennan give enjoyable performances as they always seem to do. <br /><br />But come on Hollywood - a Mountie telling the people of Dawson City, Yukon to elect themselves a marshal (yes a marshal!) and to enforce the law themselves, then gunfighters battling it out on the streets for control of the town? <br /><br />Nothing even remotely resembling that happened on the Canadian side of the border during the Klondike gold rush. Mr. Mann and company appear to have mistaken Dawson City for Deadwood, the Canadian North for the American Wild West.<br /><br />Canadian viewers be prepared for a Reefer Madness type of enjoyable howl with this ludicrous plot, or, to shake your head in disgust.',
#        b'This is the kind of film for a snowy Sunday afternoon when the rest of the world can go ahead with its own business as you descend into a big arm-chair and mellow for a couple of hours. Wonderful performances from Cher and Nicolas Cage (as always) gently row the plot along. There are no rapids to cross, no dangerous waters, just a warm and witty paddle through New York life at its best. A family film in every sense and one that deserves the praise it received.',
#        b'As others have mentioned, all the women that go nude in this film are mostly absolutely gorgeous. The plot very ably shows the hypocrisy of the female libido. When men are around they want to be pursued, but when no "men" are around, they become the pursuers of a 14 year old boy. And the boy becomes a man really fast (we should all be so lucky at this age!). He then gets up the courage to pursue his true love.'],
#       dtype=object)>

# %%
import tensorflow_hub as hub
embed = hub.load("https://kaggle.com/models/google/gnews-swivel/frameworks/TensorFlow2/variations/tf2-preview-20dim/versions/1")
embeddings = embed(["cat is on the mat", "dog is in the fog"])

# %%
hub_layer= hub.KerasLayer("https://kaggle.com/models/google/gnews-swivel/frameworks/TensorFlow2/variations/tf2-preview-20dim/versions/1", output_shape=[20],
                           input_shape=[], dtype=tf.string,trainable=True)

model = tf.keras.Sequential()
model.add(hub_layer)
model.add(tf.keras.layers.Dense(16, activation='relu'))
model.add(tf.keras.layers.Dense(1, activation='sigmoid'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  keras_layer (KerasLayer)    (None, 20)                400020
#
#  dense (Dense)               (None, 16)                336
#
#  dense_1 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 400373 (1.53 MB)
# Trainable params: 400373 (1.53 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer = 'adam',loss = tf.keras.losses.BinaryCrossentropy(from_logits=True),metrics = ['accuracy'])

# %%
history = model.fit(train_data.shuffle(10000).batch(100), epochs = 25, validation_data = val_data.batch(100),verbose = 1)
# Out:
# Epoch 1/25
# /usr/local/lib/python3.10/dist-packages/keras/src/backend.py:5818: UserWarning: "`binary_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Sigmoid activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 250/250 [==============================] - 8s 24ms/step - loss: 0.6099 - accuracy: 0.6781 - val_loss: 0.4999 - val_accuracy: 0.7637
# Epoch 2/25
# 250/250 [==============================] - 7s 27ms/step - loss: 0.4214 - accuracy: 0.8135 - val_loss: 0.3821 - val_accuracy: 0.8319
# Epoch 3/25
# 250/250 [==============================] - 5s 20ms/step - loss: 0.3211 - accuracy: 0.8678 - val_loss: 0.3270 - val_accuracy: 0.8610
# Epoch 4/25
# 250/250 [==============================] - 7s 27ms/step - loss: 0.2625 - accuracy: 0.8944 - val_loss: 0.3035 - val_accuracy: 0.8721
# Epoch 5/25
# 250/250 [==============================] - 5s 19ms/step - loss: 0.2240 - accuracy: 0.9128 - val_loss: 0.2929 - val_accuracy: 0.8780
# Epoch 6/25
# 250/250 [==============================] - 6s 24ms/step - loss: 0.1946 - accuracy: 0.9265 - val_loss: 0.2921 - val_accuracy: 0.8792
# Epoch 7/25
# 250/250 [==============================] - 5s 18ms/step - loss: 0.1715 - accuracy: 0.9376 - val_loss: 0.2960 - val_accuracy: 0.8780
# Epoch 8/25
# 250/250 [==============================] - 6s 22ms/step - loss: 0.1516 - accuracy: 0.9465 - val_loss: 0.3098 - val_accuracy: 0.8736
# Epoch 9/25
# 250/250 [==============================] - 5s 18ms/step - loss: 0.1348 - accuracy: 0.9536 - val_loss: 0.3190 - val_accuracy: 0.8759
# Epoch 10/25
# 250/250 [==============================] - 6s 24ms/step - loss: 0.1188 - accuracy: 0.9604 - val_loss: 0.3331 - val_accuracy: 0.8718
# Epoch 11/25
# 250/250 [==============================] - 5s 18ms/step - loss: 0.1064 - accuracy: 0.9662 - val_loss: 0.3532 - val_accuracy: 0.8695
# Epoch 12/25
# 250/250 [==============================] - 6s 22ms/step - loss: 0.0937 - accuracy: 0.9720 - val_loss: 0.3743 - val_accuracy: 0.8657
# Epoch 13/25
# 250/250 [==============================] - 5s 20ms/step - loss: 0.0820 - accuracy: 0.9764 - val_loss: 0.3935 - val_accuracy: 0.8627
# Epoch 14/25
# 250/250 [==============================] - 5s 19ms/step - loss: 0.0724 - accuracy: 0.9796 - val_loss: 0.4191 - val_accuracy: 0.8620
# Epoch 15/25
# 250/250 [==============================] - 6s 25ms/step - loss: 0.0626 - accuracy: 0.9840 - val_loss: 0.4453 - val_accuracy: 0.8584
# Epoch 16/25
# 250/250 [==============================] - 5s 19ms/step - loss: 0.0542 - accuracy: 0.9871 - val_loss: 0.4780 - val_accuracy: 0.8569
# Epoch 17/25
# 250/250 [==============================] - 6s 23ms/step - loss: 0.0477 - accuracy: 0.9886 - val_loss: 0.5064 - val_accuracy: 0.8546
# Epoch 18/25
# 250/250 [==============================] - 5s 20ms/step - loss: 0.0395 - accuracy: 0.9919 - val_loss: 0.5493 - val_accuracy: 0.8530
# Epoch 19/25
# 250/250 [==============================] - 6s 25ms/step - loss: 0.0341 - accuracy: 0.9939 - val_loss: 0.5802 - val_accuracy: 0.8502
# Epoch 20/25
# 250/250 [==============================] - 6s 25ms/step - loss: 0.0283 - accuracy: 0.9956 - val_loss: 0.6197 - val_accuracy: 0.8480
# Epoch 21/25
# 250/250 [==============================] - 5s 19ms/step - loss: 0.0241 - accuracy: 0.9966 - val_loss: 0.6572 - val_accuracy: 0.8449
# Epoch 22/25
# 250/250 [==============================] - 6s 24ms/step - loss: 0.0202 - accuracy: 0.9974 - val_loss: 0.6973 - val_accuracy: 0.8431
# Epoch 23/25
# 250/250 [==============================] - 5s 20ms/step - loss: 0.0164 - accuracy: 0.9983 - val_loss: 0.7374 - val_accuracy: 0.8424
# Epoch 24/25
# 250/250 [==============================] - 5s 19ms/step - loss: 0.0131 - accuracy: 0.9989 - val_loss: 0.7778 - val_accuracy: 0.8422
# Epoch 25/25
# 250/250 [==============================] - 6s 24ms/step - loss: 0.0103 - accuracy: 0.9993 - val_loss: 0.8274 - val_accuracy: 0.8395

# %%
results = model.evaluate(test_data.batch(100), verbose = 2)
# Out:
# 150/150 - 2s - loss: 0.8771 - accuracy: 0.8366 - 2s/epoch - 11ms/step
